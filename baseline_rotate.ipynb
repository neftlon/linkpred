# %% [markdown]
# The code is copied from [torchdrug's tutorial on KGE](https://torchdrug.ai/docs/tutorials/reasoning.html).

# %%
import matplotlib as mpl, matplotlib.pyplot as plt
import torch
from torchdrug import core, datasets, tasks, models
from dataset import TdLncTarD

# %%
dataset = TdLncTarD()
# Out:
# ...
# Loading data/test.tsv: 100%|█████████████████████████████████████| 678/678 [00:00<00:00, 1097968.38it/s]

# %%
train_set, valid_set, test_set = dataset.split()

# %%
model = models.RotatE(num_entity=dataset.num_entity,
                      num_relation=dataset.num_relation,
                      embedding_dim=2048, max_score=9)
task = tasks.KnowledgeGraphCompletion(model, num_negative=256,
                                      adversarial_temperature=1)

# %%
optimizer = torch.optim.Adam(task.parameters(), lr=2e-5)
solver = core.Engine(task, train_set, valid_set, test_set, optimizer,
                     gpus=[0], batch_size=1024 * 4)
solver.train(num_epoch=5)
# Out:
# 23:53:20   Preprocess training set
# 23:53:21   {'batch_size': 4096,
#  'class': 'core.Engine',
#  'gpus': [0],
#  'gradient_interval': 1,
#  'log_interval': 100,
#  'logger': 'logging',
#  'num_worker': 0,
#  'optimizer': {'amsgrad': False,
#                'betas': (0.9, 0.999),
#                'capturable': False,
#                'class': 'optim.Adam',
#                'differentiable': False,
#                'eps': 1e-08,
#                'foreach': None,
#                'fused': None,
#                'lr': 2e-05,
#                'maximize': False,
#                'weight_decay': 0},
#  'scheduler': None,
#  'task': {'adversarial_temperature': 1,
#           'class': 'tasks.KnowledgeGraphCompletion',
#           'criterion': 'bce',
#           'fact_ratio': None,
#           'filtered_ranking': True,
#           'full_batch_eval': False,
#           'margin': 6,
#           'metric': ('mr', 'mrr', 'hits@1', 'hits@3', 'hits@10'),
# ...

# %%
solver.evaluate("valid")
